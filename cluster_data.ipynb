# %%
# %matplotlib inline
from sr import cluster_data

# set up clustering for dataset
bed_fn = "data/mouse/alldata"
cluster_data(bed_fn)
# Out:
# Loading fam file data/mouse/alldata.fam
# Loading bim file data/mouse/alldata.bim
# indexing snps
# bed file is open data/mouse/alldata.bed
# using c-based plink parser
# c:\Anaconda\lib\site-packages\numpy\core\fromnumeric.py:2499: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)

# %% [raw]
# We can clearly see four large blocks, which should reflect four mouse strains, as well as many small blocks on the diagonal, which reflect the fine-grained family structure within this data set.
